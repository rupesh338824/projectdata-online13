# %%
emp = {'id':101,'name':'Arun','sal':45454}

# %%
emp
# Out:
# {'id': 101, 'name': 'Arun', 'sal': 45454}

# %%
emp['sal']
# Out:
# 45454

# %%
emp.get('sal')
# Out:
# 45454

# %%
emp.get('sal','no key present')
# Out:
# 45454

# %%
mutable type

# %%
emp
# Out:
# {'id': 101, 'name': 'Arun', 'sal': 45454}

# %%
single item

# %%
emp['dept'] = 'IT'

# %%
emp
# Out:
# {'id': 101, 'name': 'Arun', 'sal': 45454, 'dept': 'IT'}

# %%
emp['city'] = 'pune'

# %%
emp
# Out:
# {'id': 101, 'name': 'Arun', 'sal': 45454, 'dept': 'IT', 'city': 'pune'}

# %%
update({items})

# %%
emp.update({'a':100,'b':200})

# %%
emp
# Out:
# {'id': 101,
#  'name': 'Arun',
#  'sal': 45454,
#  'dept': 'IT',
#  'city': 'pune',
#  'a': 100,
#  'b': 200}

# %%
insertion 

single dict['key'] = value

dict.update({})

# %%
How to delete item

# %%
1.pop(key)
2.popitem
3.clear

# %%
emp.pop('dept')
# Out:
# 'IT'

# %%
emp
# Out:
# {'id': 101, 'name': 'Arun', 'sal': 45454, 'city': 'pune', 'a': 100, 'b': 200}

# %%
emp.pop('a')
# Out:
# 100

# %%
emp
# Out:
# {'id': 101, 'name': 'Arun', 'sal': 45454, 'city': 'pune', 'b': 200}

# %%
popitem() :

single item but -- it will follow

LIFO --

# %%
emp.popitem()
# Out:
# ('b', 200)

# %%
delete item -- return  store

# %%
empdata = {101:["Akash","Pune"],
           102:["Amit","mumbai"]
          }

# %%
empdata.popitem()
# Out:
# (102, ['Amit', 'mumbai'])

# %%
empdata
# Out:
# {101: ['Akash', 'Pune']}

# %%
empdata.popitem()
# Out:
# (101, ['Akash', 'Pune'])

# %%
empdata
# Out:
# {}

# %%
one by one element fetch -- LIFO

# %%
p = {101:{"id":545,"name":"test","sal":5435345},
     102:{"id":43543,"name":"sample","sal":545454},
     103:{"id":543543,"name":"python","sal":54345}
    }

# %%
p.popitem()
# Out:
# (103, {'id': 543543, 'name': 'python', 'sal': 54345})

# %%
p.popitem()
# Out:
# (102, {'id': 43543, 'name': 'sample', 'sal': 545454})

# %%
p.popitem()
# Out:
# (101, {'id': 545, 'name': 'test', 'sal': 5435345})

# %%
p
# Out:
# {}

# %%
emp.clear()

# %%
emp
# Out:
# {}

# %%
insertion
access
deletion

# %%
emp  = {'id': 43543, 'name': 'sample', 'sal': 545454}

# %%
emp
# Out:
# {'id': 43543, 'name': 'sample', 'sal': 545454}

# %%
emp.keys()
# Out:
# dict_keys(['id', 'name', 'sal'])

# %%
emp.values()
# Out:
# dict_values([43543, 'sample', 545454])

# %%
emp.items()
# Out:
# dict_items([('id', 43543), ('name', 'sample'), ('sal', 545454)])

# %%
list of tuple

# %%
emp.setdefault

# %%
emp
# Out:
# {'id': 43543, 'name': 'sample', 'sal': 545454}

# %%
emp.update({"a":100,"name":"Tushar","city":"Pune"})

# %%
if key present value update
if not then add complete item

# %%
emp
# Out:
# {'id': 43543, 'name': 'Tushar', 'sal': 545454, 'a': 100, 'city': 'Pune'}

# %%
emp.update({"x":6454,"y":3434,"id":600})

# %%
emp
# Out:
# {'id': 600,
#  'name': 'Tushar',
#  'sal': 545454,
#  'a': 100,
#  'city': 'Pune',
#  'x': 6454,
#  'y': 3434}

# %%
update + insert ==  upsert

# %%
setdefault:


if key present then do nothing

if not then add item into dict

# %%
emp = {'id': 600,
 'name': 'Tushar',
 'sal': 545454,
 'a': 100,}

# %%
emp
# Out:
# {'id': 600, 'name': 'Tushar', 'sal': 545454, 'a': 100}

# %%
emp.setdefault("city","pune")
# Out:
# 'pune'

# %%
emp
# Out:
# {'id': 600, 'name': 'Tushar', 'sal': 545454, 'a': 100, 'city': 'pune'}

# %%
emp.setdefault("name","Akash")
# Out:
# 'Tushar'

# %%
emp
# Out:
# {'id': 600, 'name': 'Tushar', 'sal': 545454, 'a': 100, 'city': 'pune'}

# %%
update vs setdefualt

# %%
fromkeys()

# %%
empty -- dict 

key -- >

# %%
k = ['id','name','city']

# %%
dict.fromkeys(k,0)
# Out:
# {'id': 0, 'name': 0, 'city': 0}

# %%
list:
======
insert
append
extends
remove
pop
clear
sort
sort(reverse=True)
count
index
reverse

tuple:
======
count
index


packing and unpacking

set:
add
update

remove
discard
pop
clear

union
intersection
diff
symm diff

intersection_update
diff_update
symm diff_update

issuperset
issubset
isdisjoint

dict:
get
update
dict[key] = value
keys
values
items
setdefualt
fromkeys()
clear
pop
popitem

# %%
p = (200,)

# %%
type(p)
# Out:
# tuple

# %%
Str :
=====
it is single char or multiple chars -- string
it is immutable type
it is denoted by ' ' / "  " / '''   ''' / """  """
it is having highest priority among all the DS

str is following same indexin pattern like list,tuple

# %%
it is denoted by ' ' / "  " / '''   ''' / """  """

# %%
p = 'python'

# %%
p
# Out:
# 'python'

# %%
p = "python"

# %%
p
# Out:
# 'python'

# %%
p = 'python is good in ML it's also used in Dev'
# Out:
#   Cell In[69], line 1
#     p = 'python is good in ML it's also used in Dev'
#                                                    ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
p = "python is good in ML it's also used in Dev"

# %%
p
# Out:
# "python is good in ML it's also used in Dev"

# %%
p = "python is good in ML "its" also used in Dev"
# Out:
#   Cell In[72], line 1
#     p = "python is good in ML "its" also used in Dev"
#                                ^
# SyntaxError: invalid syntax

# %%
p = 'python is good in ML "its" also used in Dev'

# %%
p
# Out:
# 'python is good in ML "its" also used in Dev'

# %%
data  = 'Documentation for Python's standard library, 
along with tutorials and guides, are available online.'
# Out:
#   Cell In[75], line 2
#     along with tutorials and guides, are available online.'
#                                                           ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
data  = "Documentation for Python's standard library, 
along with tutorials and guides, are available online."
# Out:
#   Cell In[76], line 1
#     data  = "Documentation for Python's standard library,
#             ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
' ' or "  " -- single line string

# %%
data = '''Python 3.14 is the latest stable release of the 
Python programming language, with a "mix" of changes to 'the language', 
the implementation, and the standard library. The biggest changes include 
template string literals, deferred evaluation of annotations, 
and support for subinterpreters in the standard library.'''

# %%
data
# Out:
# 'Python 3.14 is the latest stable release of the \nPython programming language, with a "mix" of changes to \'the language\', \nthe implementation, and the standard library. The biggest changes include \ntemplate string literals, deferred evaluation of annotations, \nand support for subinterpreters in the standard library.'

# %%
print(data)
# Out:
# Python 3.14 is the latest stable release of the
# Python programming language, with a "mix" of changes to 'the language',
# the implementation, and the standard library. The biggest changes include
# template string literals, deferred evaluation of annotations,
# and support for subinterpreters in the standard library.

# %%
'  ' or  " " -- single line string
''' ''' or  """  """  -- multiline string

# %%
p = 'python'

# %%
p[2]
# Out:
# 't'

# %%
p = 'p thon'

# %%
'SADF@#$@#$#$%#@%$#'

# %%
p = 'python  data'

# %%
p[6]
# Out:
# ' '

# %%
p = 'python'

# %%
p1 = p.upper()

# %%
p1
# Out:
# 'PYTHON'

# %%
p = 'JAVA'

# %%
p.lower()
# Out:
# 'java'

# %%
p = 'PyThOn'

# %%
p.swapcase()
# Out:
# 'pYtHoN'

# %%
p = 'the python world'

# %%
p.title()
# Out:
# 'The Python World'

# %%
fullname = 'keshav patil'

# %%
fullname.title()
# Out:
# 'Keshav Patil'

# %%
p = 'python book'

# %%
p.capitalize()
# Out:
# 'Python book'

# %%
p = 'pythont'

# %%
p.count('t')
# Out:
# 2

# %%
print(data)
# Out:
# Python 3.14 is the latest stable release of the
# Python programming language, with a "mix" of changes to 'the language',
# the implementation, and the standard library. The biggest changes include
# template string literals, deferred evaluation of annotations,
# and support for subinterpreters in the standard library.

# %%
data.count('Python')
# Out:
# 2

# %%
char 
word

# %%
p
# Out:
# 'pythont'

# %%
p.index('t')
# Out:
# 2

# %%
strip
split
find

# %%
p
# Out:
# 'pythont'

# %%
len(p)
# Out:
# 7

# %%
len(data)
# Out:
# 316

# %%
split(sep) -- string break -- sep -- list

# %%
fullname
# Out:
# 'keshav patil'

# %%
fullname.split(" ")[0]
# Out:
# 'keshav'

# %%
filename = 'copper_2025_daily_prd.csv'

# %%
filename.split('_')[1]
# Out:
# '2025'

# %%
email = 'rahul@gmail.com'

# %%
email.split('@')[0]
# Out:
# 'rahul'

# %%
filename = 'copper_2025-05-31_daily_prd.csv'

# %%
filename.split('_')[1].split('-')[-1]
# Out:
# '31'

# %%
filename.split('-')[-1].split('_')[0]
# Out:
# '31'

# %%
fullname.split()[0].capitalize()
# Out:
# 'Keshav'
